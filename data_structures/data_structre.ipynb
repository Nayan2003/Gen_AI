# %% [markdown]
# # Data structure in python

# %% [markdown]
# ##### data  structure in python are being used for storing the data in a structurad format so that we can access the data and along with that we can perform all of the oprations with these data structures that we can  perform in the case of databasess as well like CRUD (Create, Read, update, delete) oprations

# %% [markdown]
# ## Types of data  structure in python are :
#
# 1. List
# 2. Tuple
# 3.Set
# 4. Dictionary

# %% [markdown]
# ## The different types of data structures deffers on this basis that in which specific format we want to storethe data

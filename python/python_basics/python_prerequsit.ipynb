# %% [markdown]
# # mejor big headding

# %% [markdown]
# # python requirments

# %% [markdown]
# ## wwwwe r going to ccover python requirments

# %%
print("hwwwllo wwwwworld")
# Out:
# hwwwllo wwwwworld

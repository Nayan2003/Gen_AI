# %% [markdown]
# # Keywords

# %% [markdown]
# ### keywords are the reserved words wchich cannot be used as variable names, function names, or any other identifiers in Python. They are used to define the syntax and structure of the Python language. Here is a list of Python keywords:

# %%
list = "amit kumar singh"

# %%
print(list)
# Out:
# amit kumar singh

# %%
tuple
# Out:
# tuple

# %%
set
# Out:
# set

# %%
se
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 se
#
# NameError: name 'se' is not defined

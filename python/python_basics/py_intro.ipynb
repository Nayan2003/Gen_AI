# %% [markdown]
# # What is python language?

# %% [markdown]
# ### python is type of programming language which we can use to write code and create software applications. It is a high-level language that is easy to read and write, making it popular among beginners and experienced programmers alike. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. It has a large standard library and a vast ecosystem of third-party packages, which makes it versatile for various applications such as web development, data analysis, machine learning, and automation.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## syntax for python language

# %% [markdown]
# ### syntax refers to the set of rules that define how code should be written and structured in a programming language. In Python, the syntax is designed to be clear and readable, making it easier for developers to write and understand code. Here are some key aspects of Python syntax:

# %% [markdown]
# # Sementics of python language

# %% [markdown]
# ### Sementics of python language refers to the meaning of interpritation of symbols , characters and commands in language., it is about what the ode is suppose to do and how it is suppose to do it. It is about the meaning of the code and how it is executed by the interpreter. It is about the logic and the flow of the code. It is about how the code is structured and how it is organized. It is about how the code is written and how it is read. It is about how the code is understood and how it is interpreted by the programmer and the interpreter.

# %% [markdown]
# # Python syntax rule:

# %% [markdown]
# # 1. Python is case sensitive. For example, the variable name "myVariable" is different from "myvariable".

# %%
name = "nayan"
name2 = "Nayan"
name == name2
# Out:
# False

# %% [markdown]
# # 2. indentaton in python

# %% [markdown]
# ### indentation in python is very important. It is used to define the scope of loops, functions, and classes. In python, we use indentation to indicate a block of code. The standard indentation is 4 spaces.

# %%
age = int(input("enter your age: "))
print("your age {} is stored in variable age".format(age))
if age >10 :
    print("you r eligible for voting")
# Out:
# your age 45 is stored in variable age
# you r eligible for voting

# %% [markdown]
# ## line continuation --> we can use Backslash for continuing the stamtment on the next line

# %%
a = 10 + 20 + 30 + \
    40 + 50
print(a)
# Out:
# 150

# %%
a=5 ; b = 8

# %%
print(a)
# Out:
# 5

# %%
a=10 b=20
# Out:
#   Cell In[18], line 1
#     a=10 b=20
#          ^
# SyntaxError: invalid syntax

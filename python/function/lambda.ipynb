# %% [markdown]
# # Lambda functions

# %% [markdown]
# #### Lambda function are the one liner funccctions --> ccan write in one line

# %% [markdown]
# #### defined by the lambda keyword

# %% [markdown]
# ## Syntax for Lambda funtrion
#
# ## lambda argument:expression
#
# ## lambda --> keyword whih simpally lettt the python interpreter know that the ccurrrent funtion is our Lambda functioin
#
# ## Arguments --> Input values for our Funcction
#
# ## expression --> Logic (Funccction Body)

# %% [markdown]
# #### lambda x:x**2

# %% [markdown]
# ## they can have any number of arguments but only one expression or only one logicc
#
# ## They are used fopr short oprations or as arguments to higher order funcctions

# %% [markdown]
# ## It can be treated as a Funtion without a Name and they dont even requred a Return Statement

# %%
## Function which calulate the sqare of the numbers

def square(number):
    return number**2

# %%
square(25)
# Out:
# 625

# %%
## This similer problem an be solved using lambda funtion as well

# %%
lambda_func=lambda x:x**2

# %%
type(lambda_func)
# Out:
# function

# %%
lambda_func(5)
# Out:
# 25

# %%
## lambda function --> ccalulate the sum of 2 nnumbers

sum=lambda x,y:x+y

# %%
sum(5,6)
# Out:
# 11

# %%
product = lambda x,y,z:x*y*z

print(f"the product is below",product(4,8,3))
# Out:
# the product is below 96

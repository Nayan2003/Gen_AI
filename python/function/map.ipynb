# %% [markdown]
# # Map()

# %% [markdown]
# ### map function applies a given functi9n opration to all items in an iterable or a list and return a Map object (An iterator)

# %% [markdown]
# ## Map funtion is pertiulerly useful for Transforming the data or applying an opration on all itemsof the iterable

# %% [markdown]
# ## Map() is going to help us out with  avoiding unneccessary lines of ccode and we ccan apply the opration on all values or all items in an iterable and this is the sign of a good programmer

# %% [markdown]
# ### Santax for map()
#
#
# ## list(map(funtion,itrable))

# %%
##  Sqaaring all items of a list

list_items = [1,2,3,4,5]

def square(list_item):
    for item in list_item:
        square_item = item**2

        print(square_item)

# %%
def
